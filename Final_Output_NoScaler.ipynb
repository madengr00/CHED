# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from datetime import date, datetime
from sklearn.metrics import mean_squared_error
from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle

# %%
# Read the csv files into a pandas DataFrame
train = pd.read_csv('master_train.csv', index_col = 0)
test = pd.read_csv('master_test.csv',index_col = 0)

# %%
test.head()
# Out:
#      id  belongs_to_collection_True   budget  language_enc  popularity  \
# 0  3001                           1        0             0    3.851534
# 1  3002                           0    88000             1    3.559789
# 2  3003                           0        0             1    8.085194
# 3  3004                           0  6800000             2    8.596012
# 4  3005                           0  2000000             1    3.217680
#
#    status_Released    year  month  Action  Adventure    ...      count_cast  \
# 0                1  2007.0    7.0       0          1    ...               7
# 1                1  2058.0    5.0       0          0    ...              10
# 2                1  1997.0    5.0       0          0    ...               9
# 3                1  2010.0    9.0       0          0    ...              23
# 4                1  2005.0    2.0       0          0    ...               4
#
#    count_crew  count_staff  count_keyword  castWt  prodcoWt  keywordWt  \
# 0           2            9              2     120         0         23
# 1           8           18              8     185         5        161
# 2          10           19              4     128        44         68
# 3          69           92             15     611        38        263
# 4          14           18              4      84         0         56
#
#    crewWt  teamWt  inEnglish
# 0      36     156          1
# 1     197     387          1
# 2     157     329          1
# 3    1784    2433          1
# 4     328     412          1
#
# [5 rows x 41 columns]

# %%
train.head()
# Out:
#    id  belongs_to_collection_True    budget  language_enc  popularity  \
# 0   1                           1  14000000             0    6.575393
# 1   2                           1  40000000             0    8.248895
# 2   3                           0   3300000             0   64.299990
# 3   4                           0   1200000             1    3.174936
# 4   5                           0         0             2    1.148070
#
#    status_Released  year  month  Action  Adventure    ...     count_crew  \
# 0                1  2015      2       0          0    ...             72
# 1                1  2004      8       0          0    ...              9
# 2                1  2014     10       0          0    ...             64
# 3                1  2012      3       0          0    ...              3
# 4                1  2009      2       1          0    ...              2
#
#    count_staff  count_keyword  castWt  prodcoWt  keywordWt  crewWt  teamWt  \
# 0           96              4     597        19         80    1930    2546
# 1           29              4     385         0         53     158     543
# 2          115             12    1270        38        234    1669    2977
# 3           10              7     151         0        115      51     202
# 4            6              0      80         0          0      47     127
#
#    inEnglish   revenue
# 0          1  12314651
# 1          1  95149435
# 2          1  13092000
# 3          1  16000000
# 4          0   3923970
#
# [5 rows x 42 columns]

# %%
train.columns
# Out:
# Index(['id', 'belongs_to_collection_True', 'budget', 'language_enc',
#        'popularity', 'status_Released', 'year', 'month', 'Action', 'Adventure',
#        'Animation', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family',
#        'Fantasy', 'Foreign', 'History', 'Horror', 'Music', 'Mystery',
#        'Romance', 'Science Fiction', 'Thriller', 'War', 'Western',
#        'count_genre', 'count_country', 'count_company', 'count_splang',
#        'count_cast', 'count_crew', 'count_staff', 'count_keyword', 'castWt',
#        'prodcoWt', 'keywordWt', 'crewWt', 'teamWt', 'inEnglish', 'revenue'],
#       dtype='object')

# %%
# Assign the data to X and y
Xid = train[['id']]
X_train = train[['belongs_to_collection_True', 'budget', 'language_enc', 'popularity','year', 'month', 'count_genre',
       'count_country', 'count_company', 'count_splang', 'count_cast',
       'count_crew', 'count_staff', 'count_keyword', "castWt",'prodcoWt','keywordWt','crewWt','teamWt']]
y_train = train['revenue'].values.reshape(-1,1)
print(X_train.shape, y_train.shape)
# Out:
# (3000, 19) (3000, 1)

# %%
testID = test['id']
testID.head()
test = test[['belongs_to_collection_True', 'budget', 'language_enc', 'popularity','year', 'month', 'count_genre',
       'count_country', 'count_company', 'count_splang', 'count_cast',
       'count_crew', 'count_staff', 'count_keyword', "castWt",'prodcoWt','keywordWt', 'crewWt','teamWt']]

# %% [markdown]
# ## GradientBoostingRegressor - No Scaling

# %% [markdown]
# class sklearn.ensemble.GradientBoostingRegressor(loss=’ls’, learning_rate=0.1, n_estimators=100, subsample=1.0, criterion=’friedman_mse’, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0, min_impurity_split=None, init=None, random_state=None, max_features=None, alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False, presort=’auto’, validation_fraction=0.1, n_iter_no_change=None, tol=0.0001)[source]¶

# %%
# Fit regression model
params = {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': .01, 'loss': 'ls'} 
gbr = ensemble.GradientBoostingRegressor(**params)
predictions2 = gbr.fit(X_train,y_train)
training_score = gbr.score(X_train, y_train)
print(f"Training Score: {training_score}")
# Out:
# Training Score: 0.864439711486527

# %%
feature_names = X_train.columns

# %%
sorted(zip(gbr.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.6362778588069044, 'budget'),
#  (0.15486295268897277, 'popularity'),
#  (0.05570553720941892, 'belongs_to_collection_True'),
#  (0.036474621109835875, 'count_cast'),
#  (0.02301103549186075, 'month'),
#  (0.014729864810467624, 'prodcoWt'),
#  (0.010815378068583622, 'count_keyword'),
#  (0.01035356891029245, 'keywordWt'),
#  (0.010290112040167592, 'year'),
#  (0.008842192033791286, 'teamWt'),
#  (0.008038369275909646, 'count_staff'),
#  (0.006973682566961647, 'count_crew'),
#  (0.006551716411816692, 'castWt'),
#  (0.005584078589434093, 'count_genre'),
#  (0.004673855093180757, 'crewWt'),
#  (0.0033811536465650537, 'count_country'),
#  (0.0023389423497831587, 'count_company'),
#  (0.001019464432425537, 'count_splang'),
#  (7.561646362825688e-05, 'language_enc')]

# %%
#Make New Predictions
gbr_predictions = pd.DataFrame(gbr.predict(test), columns = ['revenue'])
output = pd.concat([testID, gbr_predictions], axis=1)
output.head()
#rf_predictions = pd.DataFrame(rf.predict(test), columns = ['revenue'])
#output = pd.concat([testID['id'], rf_predictions], axis=1)
# Out:
#      id       revenue
# 0  3001  1.712356e+07
# 1  3002  4.435667e+06
# 2  3003  1.344225e+07
# 3  3004  2.869393e+07
# 4  3005  5.089494e+06

# %%
output.to_csv("outputs/output_" + str(date.today()) + "_13" + ".csv", index=False)
